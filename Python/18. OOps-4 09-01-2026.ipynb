# %% [markdown]
# ## Class method

# %%
class Employee:
    company = "TechCorp"  # Class variable
    employee_count = 0    # Class variable
    
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
        Employee.employee_count += 1
    
    @classmethod
    def get_company(cls):  # Class method
        """Returns company name"""
        return cls.company
    
    @classmethod
    def get_employee_count(cls):  # Class method
        """Returns total employee count"""
        return cls.employee_count
    
    @classmethod
    def create_intern(cls, name):  # Alternative constructor
        """Creates an intern with default salary"""
        return cls(name, 20000)

# %%
obj = Employee("suraj", 30000)

# %%
obj.company
# Out:
# 'TechCorp'

# %%
obj.employee_count
# Out:
# 1

# %%
print(Employee.get_company())
# Out:
# TechCorp

# %%
print(Employee.get_employee_count())
# Out:
# 1

# %%
obj.create_intern("ashwin")

# %%
obj.employee_count
# Out:
# 2

# %% [markdown]
# ## Static method

# %%
class MathUtils:
    
    @staticmethod
    def add(a, b):  # Static method
        """Adds two numbers"""
        return a + b
    
    @staticmethod
    def is_even(num):  # Static method
        """Checks if number is even"""
        return num % 2 == 0
    
    @staticmethod
    def factorial(n):  # Static method
        """Calculates factorial"""
        if n <= 1:
            return 1
        return n * MathUtils.factorial(n - 1)

# %%
obj1 = MathUtils()

# %%
obj1.add(4, 9)
# Out:
# 13

# %%
obj1.factorial(5)
# Out:
# 120

# %%
class MathUtils:

    def __init__ (self, name, age):
        self.name = name
        self.age = age
    
    @staticmethod
    def add(a, b):  # Static method
        """Adds two numbers"""
        return a + b
    
    @staticmethod
    def is_even(num):  # Static method
        """Checks if number is even"""
        return num % 2 == 0
    
    @staticmethod
    def factorial(n):  # Static method
        """Calculates factorial"""
        if n <= 1:
            return 1
        return n * MathUtils.factorial(n - 1)

# %%
obj2 = MathUtils("vikas", 35)

# %%
obj2.factorial(6)
# Out:
# 720

# %%
obj2.age
# Out:
# 35
