# %%
print("hello")
# Out:
# hello

# %% [markdown]
# #### Non- iterables

# %%
int       - whole numbers (1,40, 367)
float     - decimal (2.5, 6.998)
bool      - True / False
complex   - 34 + 7j

# %% [markdown]
# #### Interables

# %%
str      - "asdkh 3453      $%^&$^  {}", '   '
list     - [1,2,3,"$", "SA"] SQURE BRACATE
tuple    - (1,2,3,"$", "SA")
set      - {2,3,4,5,5,True}CURLY BRACATE
Dict     - {"jan": 31, "feb" : 28}

# %% [markdown]
# ### Operatos

# %% [markdown]
# #### Arithmetics

# %%
add  +
sub  -
mult *
div  /
pow  **
modulo %  
floor div //

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10%3
# Out:
# 1

# %%
10//3
# Out:
# 3

# %%
3**2
# Out:
# 9

# %% [markdown]
# #### Comparision

# %%
==
>
<
>=
<=
!=

# %%
100 == 20
# Out:
# False

# %%
30 !=30
# Out:
# False

# %% [markdown]
# #### Logical

# %%
and
or
not
in
is

# %%
a = 10
b = 20
c = 30

# %%
a == 20 and b == 30
# Out:
# False

# %%
a == 10 and b == 30
# Out:
# False

# %%
T and T = T
T and F = F
F and T = F
F and F = F

# %%
T or T = T
F or T = T
T or F = T
F or F = F

# %%
not(a < 30)
# Out:
# True

# %%
list1 = [2,3,4,5,6,8]

# %%
3 in list1
# Out:
# True

# %%
10 is 20
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\amitm\AppData\Local\Temp\ipykernel_11360\3507166076.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   10 is 20
# False

# %%
a is b
# Out:
# False

# %% [markdown]
# ### Variable

# %%
name = "amit"

# %%
name
# Out:
# 'amit'

# %%
first name = "amit"
# Out:
#   Cell In[22], line 1
#     first name = "amit"
#           ^
# SyntaxError: invalid syntax

# %%
first_name = "amit"

# %%
first$name = "amit"
# Out:
#   Cell In[24], line 1
#     first$name = "amit"
#          ^
# SyntaxError: invalid syntax

# %%
_ = 48

# %%
_
# Out:
# 48

# %%
1name = "amit"
# Out:
#   Cell In[27], line 1
#     1name = "amit"
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = "amit"

# %%
name1
# Out:
# 'amit'

# %%
Name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 Name
#
# NameError: name 'Name' is not defined

# %%
a,c,b,d = 30, 29 ,40, 5

# %%
a
# Out:
# 30

# %%
b
# Out:
# 40

# %%
type(_)
# Out:
# int

# %%
type(a)
# Out:
# int

# %%
a = 6.8

# %%
type(a)
# Out:
# float

# %%
a = 10
a = 20

# %%
a
# Out:
# 20

# %%
r
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 r
#
# NameError: name 'r' is not defined

# %% [markdown]
# ### Typecasting

# %%
list("amit")
# Out:
# ['a', 'm', 'i', 't']

# %%
tuple([1,2,3,4,])
# Out:
# (1, 2, 3, 4)

# %%
str(345)
# Out:
# '345'

# %%
str({12,4,3,})
# Out:
# '{3, 12, 4}'

# %%
int("76")
# Out:
# 76

# %%
dict([2,7,8,9])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 dict([2,7,8,9])
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
list({"jan": 31, "feb" : 28})
# Out:
# ['jan', 'feb']

# %%
dict([("jan", 31),("feb",28)])
# Out:
# {'jan': 31, 'feb': 28}

# %%
{1,2,5,8,1,2}
# Out:
# {1, 2, 5, 8}
