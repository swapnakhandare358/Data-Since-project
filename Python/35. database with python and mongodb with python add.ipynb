# %% [markdown]
# ## Mysql

# %%
# !pip install pymysql

# %%
#!pip uninstall sqlalchemy

# %%
import pymysql

# %%
# make a connection with mysql
mydb = pymysql.connect(
  host="localhost",
  user="root",
  password="12345"
)

# %%
#create a database in mysql 
cursor = mydb.cursor()

# %%
cursor.execute("show databases")
for x in cursor:
  print(x)
# Out:
# ('bulk_load',)
# ('class11',)
# ('class8',)
# ('class9',)
# ('da_carburator_project',)
# ('information_schema',)
# ('laptop_data',)
# ('mysql',)
# ('performance_schema',)
# ('pydatabase',)
# ('sakila',)
# ('sys',)
# ('world',)

# %%
cursor.execute("create database newdb")
# Out:
# 1

# %%
cursor.execute("show databases")
for x in cursor:
  print(x)
# Out:
# ('bulk_load',)
# ('class11',)
# ('class8',)
# ('class9',)
# ('da_carburator_project',)
# ('information_schema',)
# ('laptop_data',)
# ('mysql',)
# ('newdb',)
# ('performance_schema',)
# ('pydatabase',)
# ('sakila',)
# ('sys',)
# ('world',)

# %%
cursor.execute("use newdb")
# Out:
# 0

# %%
cursor.execute("show tables")
for x in cursor:
  print(x)
# Out:
# ('customer',)

# %%
cursor.execute("CREATE TABLE customer (name VARCHAR(255), address VARCHAR(255))")
# Out:
# 0

# %%
cursor.execute("alter table customer add column id int first")
# Out:
# 0

# %%
sql = "INSERT INTO customer (id, name, address) VALUES (%s, %s, %s)"

val = ("1","ROHIT", "Highway 21")

cursor.execute(sql, val)

mydb.commit()

# %%
cursor.execute("select * from customer")

for i in cursor:
    print(i)
# Out:
# (1, 'ROHIT', 'Highway 21')
# (1, 'ROHIT', 'Highway 21')

# %%
sql = "INSERT INTO customer(id, name, address) VALUES (%s, %s, %s)"
val = [("2","ROHIT", "Highway 21"),
  ("3", 'Peter', 'Lowstreet 4'),
  ("4",'Ammy', 'Apple st 652'),
  ("5",'Huma', 'Mountain 21')]

# %%
cursor.executemany(sql, val)
# Out:
# 4

# %%
mydb.commit()

# %%
cursor.execute("select * from customer")

for i in cursor:
    print(i)
# Out:
# (1, 'john', 'Highway 21')
# (1, 'john', 'Highway 21')
# (3, 'Peter', 'Lowstreet 4')
# (4, 'Ammy', 'Apple st 652')
# (5, 'Huma', 'Mountain 21')

# %%
sql = "UPDATE customer SET name = 'john' WHERE id = '1'"

cursor.execute(sql)

mydb.commit()

print(cursor.rowcount, "record(s) affected")
# Out:
# 2 record(s) affected

# %%
sql = "DELETE FROM customer WHERE id = '2'"

cursor.execute(sql)

mydb.commit()

print(cursor.rowcount, "record(s) deleted")
# Out:
# 0 record(s) deleted

# %%
cursor.execute("select * from customer where id in (3,4,5)")
for i in cursor:
    print(i)
# Out:
# (3, 'Peter', 'Lowstreet 4')
# (4, 'Ammy', 'Apple st 652')
# (5, 'Huma', 'Mountain 21')

# %%
cursor.execute("use laptop_data")
# Out:
# 0

# %%
cursor.execute("select * from laptop_price")

for i in cursor:
    print(i)
# Out:
# ('LTP00001', 'Avita', 'Notebook', 'i5-11400H', '8GB', '256GB SSD', 'None', 'Integrated', 14.0, 'FHD', 1.5, 'Windows 11', 'Notebook', 5.5, 'No', 42000, None)
# ('LTP00002', 'Microsoft', 'Notebook', 'Ryzen 7 5700U', '16GB', '256GB SSD', 'None', 'MX550 2GB', 14.0, 'FHD', 1.8, 'Windows 11', 'Notebook', 5.8, 'No', 93000, None)
# ('LTP00003', 'HP', 'Netbook', 'i3-1215U', '8GB', '512GB HDD', 'None', 'MX550 2GB', 11.6, 'FHD', 1.1, 'macOS', 'Netbook', 8.2, 'No', 33000, None)
# ('LTP00004', 'Apple', 'Ultrabook', 'Apple M1', '4GB', '256GB SSD', 'None', 'Integrated', 13.3, 'Retina', 1.9, 'macOS', 'Ultrabook', 17.2, 'No', 88000, None)
# ('LTP00005', 'Apple', 'Notebook', 'Apple M1 Pro', '8GB', '512GB SSD', 'None', 'Integrated', 14.0, 'Retina', 2.0, 'macOS', 'Notebook', 13.0, 'No', 112000, None)
# ('LTP00006', 'MSI', 'Notebook', 'i9-12900H', '8GB', '256GB SSD', 'None', 'Integrated', 15.6, 'FHD', 1.7, 'macOS', 'Notebook', 9.7, 'No', 95000, None)
# ...

# %%
cursor.execute("SELECT * FROM laptop_price")
rows = cursor.fetchall()

# %%
rows
# Out:
# (('LTP00001',
#   'Avita',
#   'Notebook',
#   'i5-11400H',
#   '8GB',
#   '256GB SSD',
#   'None',
#   'Integrated',
#   14.0,
#   'FHD',
#   1.5,
#   'Windows 11',
#   'Notebook',
#   5.5,
#   'No',
#   42000,
#   None),
#  ('LTP00002',
#   'Microsoft',
#   'Notebook',
#   'Ryzen 7 5700U',
#   '16GB',
#   '256GB SSD',
#   'None',
#   'MX550 2GB',
#   14.0,
#   'FHD',
#   1.8,
#   'Windows 11',
#   'Notebook',
#   5.8,
#   'No',
#   93000,
#   None),
#  ('LTP00003',
#   'HP',
#   'Netbook',
#   'i3-1215U',
#   '8GB',
#   '512GB HDD',
#   'None',
#   'MX550 2GB',
#   11.6,
#   'FHD',
#   1.1,
#   'macOS',
#   'Netbook',
#   8.2,
#   'No',
#   33000,
#   None),
#  ('LTP00004',
#   'Apple',
#   'Ultrabook',
#   'Apple M1',
#   '4GB',
#   '256GB SSD',
#   'None',
#   'Integrated',
#   13.3,
#   'Retina',
#   1.9,
#   'macOS',
#   'Ultrabook',
#   17.2,
#   'No',
#   88000,
#   None),
#  ('LTP00005',
#   'Apple',
#   'Notebook',
#   'Apple M1 Pro',
#   '8GB',
#   '512GB SSD',
# ...

# %%
import pandas as pd

# %%
columns = [col[0] for col in cursor.description]
df = pd.DataFrame(rows, columns=columns)

# %%
columns
# Out:
# ['SKU',
#  'Brand',
#  'Model',
#  'CPU',
#  'RAM',
#  'Primary_Storage',
#  'Secondary_Storage',
#  'GPU',
#  'Screen_Size',
#  'Resolution',
#  'Weight_kg',
#  'OS',
#  'Type',
#  'Battery_Hours',
#  'Touchscreen',
#  'Price_INR',
#  'price_cat']

# %%
df.head()
# Out:
#         SKU      Brand      Model            CPU   RAM Primary_Storage  \
# 0  LTP00001      Avita   Notebook      i5-11400H   8GB       256GB SSD
# 1  LTP00002  Microsoft   Notebook  Ryzen 7 5700U  16GB       256GB SSD
# 2  LTP00003         HP    Netbook       i3-1215U   8GB       512GB HDD
# 3  LTP00004      Apple  Ultrabook       Apple M1   4GB       256GB SSD
# 4  LTP00005      Apple   Notebook   Apple M1 Pro   8GB       512GB SSD
#
#   Secondary_Storage         GPU  Screen_Size Resolution  Weight_kg  \
# 0              None  Integrated         14.0        FHD        1.5
# 1              None   MX550 2GB         14.0        FHD        1.8
# 2              None   MX550 2GB         11.6        FHD        1.1
# 3              None  Integrated         13.3     Retina        1.9
# 4              None  Integrated         14.0     Retina        2.0
#
#            OS       Type  Battery_Hours Touchscreen  Price_INR price_cat
# ...

# %%
df.shape
# Out:
# (5000, 17)

# %%
# ---- A. Read the CSV File ----
csv_path = "F:\\01. The Data Psychology\\4. New_Machine_Learning\\laptop price prediction\\31. Laptop_CSV_File.csv"
df1 = pd.read_csv(csv_path)

# %%
df1.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df1.shape
# Out:
# (1303, 12)

# %%
# Optional: Rename 'Unnamed: 0' column to 'id' for clarity
df1= df1.iloc[:,1:]

# %%
df1.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
cursor.execute("use newdb")
# Out:
# 0

# %%
create_table_query = """
CREATE TABLE IF NOT EXISTS laptops (
    Company VARCHAR(255),
    TypeName VARCHAR(255),
    Inches FLOAT,
    ScreenResolution VARCHAR(255),
    Cpu VARCHAR(255),
    Ram VARCHAR(20),
    Memory VARCHAR(255),
    Gpu VARCHAR(255),
    OpSys VARCHAR(255),
    Weight VARCHAR(20),
    Price FLOAT
)
"""

# %%
cursor.execute(create_table_query)
# Out:
# 0

# %%
insert_query = """
INSERT INTO laptops (Company, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price)
VALUES ( %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
ON DUPLICATE KEY UPDATE 
    Company=VALUES(Company), TypeName=VALUES(TypeName), Inches=VALUES(Inches),
    ScreenResolution=VALUES(ScreenResolution), Cpu=VALUES(Cpu), Ram=VALUES(Ram),
    Memory=VALUES(Memory), Gpu=VALUES(Gpu), OpSys=VALUES(OpSys), Weight=VALUES(Weight), Price=VALUES(Price)
"""

# %%
data_tuples = [tuple(row) for row in df1.values]

# %%
data_tuples
# Out:
# [('Apple',
#   'Ultrabook',
#   13.3,
#   'IPS Panel Retina Display 2560x1600',
#   'Intel Core i5 2.3GHz',
#   '8GB',
#   '128GB SSD',
#   'Intel Iris Plus Graphics 640',
#   'macOS',
#   '1.37kg',
#   71378.6832),
#  ('Apple',
#   'Ultrabook',
#   13.3,
#   '1440x900',
#   'Intel Core i5 1.8GHz',
#   '8GB',
#   '128GB Flash Storage',
#   'Intel HD Graphics 6000',
#   'macOS',
#   '1.34kg',
#   47895.5232),
#  ('HP',
#   'Notebook',
#   15.6,
#   'Full HD 1920x1080',
#   'Intel Core i5 7200U 2.5GHz',
#   '8GB',
#   '256GB SSD',
#   'Intel HD Graphics 620',
#   'No OS',
#   '1.86kg',
#   30636.0),
#  ('Apple',
#   'Ultrabook',
#   15.4,
#   'IPS Panel Retina Display 2880x1800',
#   'Intel Core i7 2.7GHz',
#   '16GB',
#   '512GB SSD',
#   'AMD Radeon Pro 455',
#   'macOS',
#   '1.83kg',
#   135195.336),
#  ('Apple',
#   'Ultrabook',
#   13.3,
#   'IPS Panel Retina Display 2560x1600',
#   'Intel Core i5 3.1GHz',
#   '8GB',
#   '256GB SSD',
#   'Intel Iris Plus Graphics 650',
# ...

# %%
cursor.executemany(insert_query, data_tuples)
mydb.commit()

# %%
cursor.execute("select * from laptops")

for i in cursor:
    print(i)
# Out:
# ('Apple', 'Ultrabook', 13.3, 'IPS Panel Retina Display 2560x1600', 'Intel Core i5 2.3GHz', '8GB', '128GB SSD', 'Intel Iris Plus Graphics 640', 'macOS', '1.37kg', 71378.7)
# ('Apple', 'Ultrabook', 13.3, '1440x900', 'Intel Core i5 1.8GHz', '8GB', '128GB Flash Storage', 'Intel HD Graphics 6000', 'macOS', '1.34kg', 47895.5)
# ('HP', 'Notebook', 15.6, 'Full HD 1920x1080', 'Intel Core i5 7200U 2.5GHz', '8GB', '256GB SSD', 'Intel HD Graphics 620', 'No OS', '1.86kg', 30636.0)
# ('Apple', 'Ultrabook', 15.4, 'IPS Panel Retina Display 2880x1800', 'Intel Core i7 2.7GHz', '16GB', '512GB SSD', 'AMD Radeon Pro 455', 'macOS', '1.83kg', 135195.0)
# ('Apple', 'Ultrabook', 13.3, 'IPS Panel Retina Display 2560x1600', 'Intel Core i5 3.1GHz', '8GB', '256GB SSD', 'Intel Iris Plus Graphics 650', 'macOS', '1.37kg', 96095.8)
# ('Acer', 'Notebook', 15.6, '1366x768', 'AMD A9-Series 9420 3GHz', '4GB', '500GB HDD', 'AMD Radeon R5', 'Windows 10', '2.1kg', 21312.0)
# ...

# %% [markdown]
# ## MongoDB

# %%
url = "mongodb+srv://amitkm644_db_user:12345@cluster0.zbnbf7h.mongodb.net/?appName=Cluster0"

# %%
# !pip install pymongo

# %%
import pymongo

# %%
client = pymongo.MongoClient(url)

# %%
database = client["AIML"]

# %%
collection = database["laptop_price"]

# %%
df1.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
data_dict = df1.to_dict("records")

# %%
data_dict
# Out:
# [{'Company': 'Apple',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': 'IPS Panel Retina Display 2560x1600',
#   'Cpu': 'Intel Core i5 2.3GHz',
#   'Ram': '8GB',
#   'Memory': '128GB SSD',
#   'Gpu': 'Intel Iris Plus Graphics 640',
#   'OpSys': 'macOS',
#   'Weight': '1.37kg',
#   'Price': 71378.6832},
#  {'Company': 'Apple',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': '1440x900',
#   'Cpu': 'Intel Core i5 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '128GB Flash Storage',
#   'Gpu': 'Intel HD Graphics 6000',
#   'OpSys': 'macOS',
#   'Weight': '1.34kg',
#   'Price': 47895.5232},
#  {'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
#   'Gpu': 'Intel HD Graphics 620',
#   'OpSys': 'No OS',
#   'Weight': '1.86kg',
#   'Price': 30636.0},
#  {'Company': 'Apple',
#   'TypeName': 'Ultrabook',
# ...

# %%
# Insert into MongoDB
collection.insert_many(data_dict)

print("CSV data has been inserted into MongoDB!")
# Out:
# CSV data has been inserted into MongoDB!

# %%
cursor = collection.find()

# %%
cursor

# %%
list(cursor)
# Out:
# [{'_id': ObjectId('698d5b64d929263d0f2a0a5f'),
#   'Company': 'Apple',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': 'IPS Panel Retina Display 2560x1600',
#   'Cpu': 'Intel Core i5 2.3GHz',
#   'Ram': '8GB',
#   'Memory': '128GB SSD',
#   'Gpu': 'Intel Iris Plus Graphics 640',
#   'OpSys': 'macOS',
#   'Weight': '1.37kg',
#   'Price': 71378.6832},
#  {'_id': ObjectId('698d5b64d929263d0f2a0a60'),
#   'Company': 'Apple',
#   'TypeName': 'Ultrabook',
#   'Inches': 13.3,
#   'ScreenResolution': '1440x900',
#   'Cpu': 'Intel Core i5 1.8GHz',
#   'Ram': '8GB',
#   'Memory': '128GB Flash Storage',
#   'Gpu': 'Intel HD Graphics 6000',
#   'OpSys': 'macOS',
#   'Weight': '1.34kg',
#   'Price': 47895.5232},
#  {'_id': ObjectId('698d5b64d929263d0f2a0a61'),
#   'Company': 'HP',
#   'TypeName': 'Notebook',
#   'Inches': 15.6,
#   'ScreenResolution': 'Full HD 1920x1080',
#   'Cpu': 'Intel Core i5 7200U 2.5GHz',
#   'Ram': '8GB',
#   'Memory': '256GB SSD',
# ...

# %%
df2 = pd.DataFrame(list(cursor))

# %%
df2.head()
# Out:
#                         _id Company   TypeName  Inches  \
# 0  698d5b64d929263d0f2a0a5f   Apple  Ultrabook    13.3
# 1  698d5b64d929263d0f2a0a60   Apple  Ultrabook    13.3
# 2  698d5b64d929263d0f2a0a61      HP   Notebook    15.6
# 3  698d5b64d929263d0f2a0a62   Apple  Ultrabook    15.4
# 4  698d5b64d929263d0f2a0a63   Apple  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# ...
