# %% [markdown]
# ## Data types

# %%
int - whole numbers  #12,3,4,4,
float - decimal
complex - 45 + 7j
bool - True/ False

# %%
string - " ", ' '
list - []
tuple - ()
set - {}
dict - {}

# %%
l = [2,3,4,5,5,"S", True, 33 + 4j, (1,2,3,), {3,4,5,}, {"a":1, "b":2}]

# %%
t = (2,3,4,5,5,"S", True, 33 + 4j, (1,2,3,), {3,4,5,}, {"a":1, "b":2})

# %%
s = {2,3,4,5,5,"S", True, 33 + 4j, (1,2,3,)}

# %%
str1 = "2,3,4,5,5,'s', True, 33 + 4j"

# %%
d = {"a":1, "b":2}

# %% [markdown]
# ## Operators

# %% [markdown]
# ### Arithmetics

# %%
+
-
*
/
//
%
**

# %%
4 + 6
# Out:
# 10

# %%
6 - 7
# Out:
# -1

# %%
30 *2
# Out:
# 60

# %%
30/4
# Out:
# 7.5

# %%
30//4
# Out:
# 7

# %%
30%4
# Out:
# 2

# %%
3**3
# Out:
# 27

# %% [markdown]
# ### Comparision

# %%
==
!=
>
<
>=
<=

# %%
4 == 7
# Out:
# False

# %%
3 > 4
# Out:
# False

# %%
3 < 5
# Out:
# True

# %%
3!=5
# Out:
# True

# %% [markdown]
# ### Logical Operators

# %%
and
or
in
is
not

# %%
a, b , c = 10,20, 30

# %%
a < b and c > b
# Out:
# True

# %%
a > b and c > b
# Out:
# False

# %%
a < b or c > b
# Out:
# True

# %%
a > b or c > b
# Out:
# True

# %%
3 not in l
# Out:
# False

# %%
4 in l
# Out:
# True

# %%
l
# Out:
# [2, 3, 4, 5, 5, 'S', True, (33+4j), (1, 2, 3), {3, 4, 5}, {'a': 1, 'b': 2}]

# %%
t
# Out:
# (2, 3, 4, 5, 5, 'S', True, (33+4j), (1, 2, 3), {3, 4, 5}, {'a': 1, 'b': 2})

# %%
l == t
# Out:
# True

# %%
l is t
# Out:
# True

# %% [markdown]
# ### Assignment operator

# %%
=

# %%
a = 8

# %%
10 = b
# Out:
#   Cell In[34], line 1
#     10 = b
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# ## variables

# %%
name = "amit"

# %%
1name = "amit"
# Out:
#   Cell In[36], line 1
#     1name = "amit"
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = "amit"

# %%
first name = "amit"
# Out:
#   Cell In[38], line 1
#     first name = "amit"
#           ^
# SyntaxError: invalid syntax

# %%
first_name = "amit"

# %%
first&name = "amit"
# Out:
#   Cell In[40], line 1
#     first&name = "amit"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
first_name = "amit"

# %%
_ = "amit"

# %%
_
# Out:
# 'amit'

# %%
a,b,c,d = 10,20,30,40

# %%
l1 = [2,3,4]

# %%
x,y,z = l1

# %%
x
# Out:
# 2

# %%
y
# Out:
# 3

# %%
z
# Out:
# 4

# %% [markdown]
# ## Type casting

# %%
a = 10

# %%
str(a)
# Out:
# '10'

# %%
str(78)
# Out:
# '78'

# %%
"35"
# Out:
# '35'

# %%
str
# Out:
# "2,3,4,5,5,'s', True, 33 + 4j"

# %%
del(str)

# %%
tuple(l)
# Out:
# (2, 3, 4, 5, 5, 'S', True, (33+4j), (1, 2, 3), {3, 4, 5}, {'a': 1, 'b': 2})

# %%
list(t)
# Out:
# [2, 3, 4, 5, 5, 'S', True, (33+4j), (1, 2, 3), {3, 4, 5}, {'a': 1, 'b': 2}]

# %%
s2 = "amit"

# %%
int(s2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 int(s2)
#
# ValueError: invalid literal for int() with base 10: 'amit'

# %%
s3 = "2342"

# %%
type(s3)
# Out:
# str

# %%
int(s3)
# Out:
# 2342

# %%
d1 = {"a":1, "b":2}

# %%
a,b = d1

# %%
a
# Out:
# 'a'

# %%
b
# Out:
# 'b'

# %% [markdown]
# ## Built-in function

# %%
print("kuchh bhi", 35)
# Out:
# kuchh bhi 35

# %%
print()

# %%
float(input())
# Out:
#  3454
# 3454.0

# %%
list(input())
# Out:
#  234234
# ['2', '3', '4', '2', '3', '4']

# %%
len(name)
# Out:
# 4

# %%
name
# Out:
# 'amit'

# %%
len(t)
# Out:
# 11

# %%
t
# Out:
# (2, 3, 4, 5, 5, 'S', True, (33+4j), (1, 2, 3), {3, 4, 5}, {'a': 1, 'b': 2})

# %%
type(l1)
# Out:
# list

# %%
type(a)
# Out:
# str

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ## Special character

# %%
#comment

# %%
new_str = """Special character
Special cha
Special character"""

# %%
new_str
# Out:
# 'Special character\nSpecial cha\nSpecial character'

# %%
independence = "1947"

# %%
print(independence)
# Out:
# 1947

# %%
independence = '"1947"'

# %%
print(independence)
# Out:
# "1947"

# %%
s4 = "Special\ncharacter"

# %%
print(s4)
# Out:
# Special
# character

# %%
s4 = "Special\tcharacter"

# %%
print(s4)
# Out:
# Special	character

# %%
s4 = "Special\rcharacter"

# %%
print(s4)
# Out:
# character

# %% [markdown]
# # Heading

# %% [markdown]
# ## heading

# %% [markdown]
# ### heading

# %% [markdown]
# new_str = """Special character
# Special cha
# Special character"""

# %% [raw]
# new_str = """Special character
# Special cha
# Special character"""

# %%
x = 6

# %%
x = x + 1

# %%
x
# Out:
# 8

# %%
x += 1

# %%
a = 2

# %%
a**=2

# %%
a
# Out:
# 256

# %%
filepath = "C:\Users\amitm\Downloads\Analyst project.pdf"

# %%
filepath = "C:\\Users\\amitm\\Downloads\\Analyst project.pdf"

# %%
filepath = "C:/Users/amitm/Downloads/Analyst project.pdf"
