# %%
l = [1,2,3,4,"sudh" ,"kumar" , 45.56, "python", 6,3]

# %%
l
# Out:
# [1, 2, 3, 4, 'sudh', 'kumar', 45.56, 'python', 6, 3]

# %%
for i in l:                       #only intejer numbers run karneke liye pass use hota hai
    if type(i) == int:
        pass
        print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 3

# %%
for i in l:
    pass

# %%
for i in l:                       #kisi list ke andar ke number par break karna ho ya stop karvana ho kisi intijar ko ya list ko break karvana ho
    print(i)  
    if i == 4:
        break
# Out:
# 1
# 2
# 3
# 4

# %%
l
# Out:
# [1, 2, 3, 4, 'sudh', 'kumar', 45.56, 'python', 6, 3]

# %%
for i in l:
    print(i)  
    if i == "kumar":
        break
# Out:
# 1
# 2
# 3
# 4
# sudh
# kumar

# %%
for i in l:                 #kisi list ke andar ke kisi intijar ya number ko  hatana ho (delete) karna ho

    if i == "kumar":
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# sudh
# 45.56
# python
# 6
# 3

# %%
for i in l:               #else ke andar print karne list me agar koi intijar ya list ko end me lagana ho uske liye
    print(i)
else:
    print("final loop")
# Out:
# 1
# 2
# 3
# 4
# sudh
# kumar
# 45.56
# python
# 6
# 3
# final loop

# %%
s = "sudhanshu"

for i in s :
    if i == 'n' :
        break
    print(i)
else :
    print("print srtring " , s )
# Out:
# s
# u
# d
# h
# a

# %%
s = "sudhanshu"

for i in s :
    if i == 'n' :
        continue
    print(i)
else :
    print("print srtring " , s )
# Out:
# s
# u
# d
# h
# a
# s
# h
# u
# print srtring  sudhanshu

# %%
l
# Out:
# [1, 2, 3, 4, 'sudh', 'kumar', 45.56, 'python', 6, 3]

# %%
i = 0
while i < len(l):
    print( i, l[i])
    i = i+1
    
print("Length of list ", len(l))
# Out:
# 0 1
# 1 2
# 2 3
# 3 4
# 4 sudh
# 5 kumar
# 6 45.56
# 7 python
# 8 6
# 9 3
# Length of list  10

# %%
for i in range(len(l)):
    print(i, "-", l[i])
# Out:
# 0 - 1
# 1 - 2
# 2 - 3
# 3 - 4
# 4 - sudh
# 5 - kumar
# 6 - 45.56
# 7 - python
# 8 - 6
# 9 - 3

# %%
count = 3

for i in range(count):
    name = input("Enter the name : ")
    print()
    print('You entered ', name)
# Out:
# Enter the name :  amit
# You entered  amit
# Enter the name :  rohit
# You entered  rohit
# Enter the name :  anuj
# You entered  anuj

# %%
name = ""

while name != "Quit":
    name = input("Enter the name (use 'Quit' to stop :")
    if name != "Quit":
        print('You entered ', name)
# Out:
# Enter the name (use 'Quit' to stop : quit
# You entered  quit
# Enter the name (use 'Quit' to stop : amit
# You entered  amit
# Enter the name (use 'Quit' to stop : python
# You entered  python
# Enter the name (use 'Quit' to stop : adskjh
# You entered  adskjh
# Enter the name (use 'Quit' to stop : e4w
# You entered  e4w
# Enter the name (use 'Quit' to stop : Quit

# %%
# Example
i = 0            

while i < 7:      
    if i > 3 :   
        print(i)     
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3
# 4
# 4
# 5
# 5
# 6
# 6

# %%
# Example
i = 0            
while i < 7:     
    if i > 3 :   
        pass   
        print(i)     
    i = i + 1
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 4
# 5
# 5
# 6
# 6
# 7

# %%
stmt = ""

while stmt != 'Quit':
    stmt = input("Enter the stmt (Use 'Quit' to stop )")
    if stmt.startswith("#") :
        continue
    if len(stmt) > 0 :
        print(stmt)
# Out:
# Enter the stmt (Use 'Quit' to stop ) python
# python
# Enter the stmt (Use 'Quit' to stop ) #python
# Enter the stmt (Use 'Quit' to stop ) Quit
# Quit

# %%
rows = 5

for i in range(rows):   # 0, 1, 2
    # nested loop
    for j in range(i):   # 0,1,2
        # display number
        print(i, end=' ')
    # new line after each row
    print('')
# Out:
# 1
# 2 2
# 3 3 3
# 4 4 4 4

# %%
list(range(3))
# Out:
# [0, 1, 2]

# %%
for i in range(4):
    for j in range(3):
        print(j)
    print(i)
# Out:
# 0
# 1
# 2
# 0
# 0
# 1
# 2
# 1
# 0
# 1
# 2
# 2
# 0
# 1
# 2
# 3

# %%
rows = 5

for i in range(0, rows):
    
    for j in range(0, i + 1):
       
        print("*", end=' ')

    print("\r")
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
rows = 5
for i in range(rows + 1, 0, -1):
    # nested reverse loop
    for j in range(0, i - 1):
        # display star
        print("*", end=' ')
    print(" ")
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
# number of rows
rows = 5
k = 2 * rows - 2
for i in range(0, rows):
    for j in range(0, k):
        print(end=" ")
    k = k - 2
    for j in range(0, i + 1):
        print("*-", end="")
    print("")
# Out:
#         *-
#       *-*-
#     *-*-*-
#   *-*-*-*-
# *-*-*-*-*-

# %%
rows = 5
k = 2 * rows - 2
for i in range(rows, -1, -1):
    for j in range(k, 0, -1):
        print(end=" ")
    k = k + 1
    for j in range(0, i + 1):
        print("*", end=" ")
    print("")

# %%
# number of rows
rows = 5
k = 2 * rows - 2
for i in range(0, rows):
    # process each column
    for j in range(0, k):
        # print space in pyramid
        print(end=" ")
    k = k - 2
    for j in range(0, i + 1):
        # display star
        print("* ", end="")
    print("")


for i in range(0, rows):
    # nested loop for each column
    for j in range(0, i + 1):
        # print star
        print("*", end=' ')
    # new line after each row
    print("\r")

# %%
rows = 5
k = 2 * rows - 2

for i in range(rows, -1, -1):
    for j in range(k, 0, -1):
        print(end=" ")
    k = k + 1
    for j in range(0, i + 1):
        print("*", end=" ")
    print("")

# %%
rows = 5
num = rows
# reverse for loop
for i in range(rows, 0, -1):
    for j in range(5-i):
        print(" "*j, end = "")
    for j in range(0, i):
        print("&", end=' ')
    print("\r")
