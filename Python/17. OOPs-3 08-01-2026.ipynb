# %%
# class
# __inti__ = constructor
# self = pointer
# def = method
# package  (directory) 
# module   (file)
# inheritence
# multilevel inheritence
# multiple inheritence
# hirerachical 
# hybrid
# overide method
# public
# private
# protective
# encapsulation
# polymorphism 
# data abstraction

# %%
class bank :
    print("this will show you your account open status ")
    def deposite(self):
        print("this will show your deposited amount")
    def test(self):                          # override code
        print("this is a test method form bank class ")


class HDFC_bank:
    def hdfc_to_icici(self):
        print("this will show you all the transaction happend to icici throuhg hdfc")
    def test(self):           #override code
        print("this is a test method form hdfc bank ")

class ineron_bank:
    def account_status_icici(self):
        print("print a account status in icici ")

class icici(HDFC_bank, bank,  ineron_bank):      # multiple inheritence
    pass

# %%
icici.mro()
# Out:
# [__main__.icici,
#  __main__.HDFC_bank,
#  __main__.bank,
#  __main__.ineron_bank,
#  object]

# %%
# Parent class
class Vehicle:
    def general_info(self):
        print("Vehicles are used for transportation.")

# Child class 1 (inherits from Vehicle)
class Car(Vehicle):
    def car_info(self):
        print("Car has 4 wheels.")

# Child class 2 (inherits from Vehicle)
class Bike(Vehicle):
    def bike_info(self):
        print("Bike has 2 wheels.")

# Grandchild class (inherits from both Car and Bike)
class Electric(Bike, Car ):
    def electric_info(self):
        print("Electric bike runs on battery.")

# %%
Electric.mro()
# Out:
# [__main__.Electric, __main__.Bike, __main__.Car, __main__.Vehicle, object]

# %% [markdown]
# ## Encapsulation

# %%
class Car:
    def __init__(self, brand, speed=0):
        self.__brand = brand  # Private attribute
        self.__speed = speed  # Private attribute

    def accelerate(self, increase):
        self.__speed += increase

    def get_speed(self):
        return self.__speed

    def get_brand(self):
        return self.__brand

# %%
obj = Car("BMW")

# %%
obj.get_brand()
# Out:
# 'BMW'

# %%
obj.get_speed()
# Out:
# 0

# %%
obj.accelerate(40)

# %%
obj.get_speed()
# Out:
# 40

# %%
class ineuron2:                      # encpsulation 
    def __init__(self):
        self.students1 = "data science"

    def students(self):
        print(self.students1)


class ineuron3:
    def __init__(self):
        self.__students1 = "data science "

    def students(self):
        print(self.__students1)
        
    def student_change(self,new_value):
        self.__students1 = new_value

# %%
obj1 = ineuron2()

# %%
obj1.students1
# Out:
# 'data science'

# %%
obj1.students()
# Out:
# data science

# %%
obj1.students1 = "data engineer"

# %%
obj1.students1
# Out:
# 'data engineer'

# %%
obj2 = ineuron3()

# %%
obj2.students()
# Out:
# data science

# %%
obj2.student_change("data analyst")

# %%
obj2.students()
# Out:
# data analyst

# %%
obj2._ineuron3__students1 = "business analyst"

# %%
obj2.students()
# Out:
# business analyst

# %% [markdown]
# ## Polymorphism

# %%
class Vehicle:
    def move(self):
        return "Vehicle is moving."

class Car(Vehicle):
    def move(self):  # Overrides parent method
        return "Car is driving on the road."

class Boat(Vehicle):
    def move(self):  # Overrides parent method
        return "Boat is sailing on water."

# %%
# Usage
vehicles = [Vehicle(), Car(), Boat()]

for i in vehicles:
    print(i.move())
# Out:
# Vehicle is moving.
# Car is driving on the road.
# Boat is sailing on water.

# %% [markdown]
# ### it is also called duck typing

# %%
class ineuron4:
    def students(self):
        print("print a students details ")

class class_type :
    def student(self):
        print("print the class type of students")

# %%
def ineuron_external(a,b):
    a.students()
    b.student()

# %%
ineuron_external(ineuron4(),class_type())
# Out:
# print a students details
# print the class type of students

# %% [markdown]
# ## super()  key word

# %%
# Parent class
class Vehicle:
    def general_info(self):
        print("Vehicles are used for transportation.")

# Child class 1  
class Car(Vehicle):
    def general_info(self):
        super().general_info()
        print("car class--- Vehicles are used for transportation.")
    
    def car_info(self):
        print("Car has 4 wheels.")

# %%
obj3 = Vehicle()

# %%
obj3.general_info()
# Out:
# Vehicles are used for transportation.

# %%
obj4 = Car()

# %%
obj4.general_info()
# Out:
# Vehicles are used for transportation.
# car class--- Vehicles are used for transportation.

# %%
# Parent class
class Vehicle:
    brand = "TATA"

    def general_info(self):
        print("Vehicles are used for transportation.")

# Child class 1  
class Car(Vehicle):

    def general_info(self):
        print("car class--- Vehicles are used for transportation.")
        super().general_info()
    
    def car_info(self):
        print("Car has 4 wheels.")

# %%
obj5 = Car()

# %%
obj5.general_info()
# Out:
# car class--- Vehicles are used for transportation.
# Vehicles are used for transportation.

# %%
 
class Vehicle1:
    brand = "TATA"

    def general_info(self):
        print("Vehicles are used for transportation.")

 
class Car1:

    def general_info(self):
        print("car class--- Vehicles are used for transportation.")
        super().general_info()
    
    def car_info(self):
        print("Car has 4 wheels.")

# %%
obj6 = Car1()

# %%
obj6.general_info()
# Out:
# car class--- Vehicles are used for transportation.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 obj6.general_info()
#
# Cell In[66], line 12, in Car1.general_info(self)
#      10 def general_info(self):
#      11     print("car class--- Vehicles are used for transportation.")
# ---> 12     super().general_info()
#
# AttributeError: 'super' object has no attribute 'general_info'

# %%
# class
# __inti__ = constructor
# self = pointer
# def = method
# package  (directory) 
# module   (file)
# inheritence
# multilevel inheritence
# multiple inheritence
# hirerachical 
# hybrid
# overide method
# public
# private
# protective
# data abstraction 
# encapsulation
# polymorphism
